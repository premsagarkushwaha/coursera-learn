# %% [markdown]
# # 2. Information Retrieval

# %%
import numpy as np
import pandas as pd
import nltk
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.neighbors import KDTree

# %% [markdown]
# # imorting dataset

# %%
ds= pd.read_csv('log4shell_tweets.csv', usecols=["text", "user_name"])

# %%
ds   = ds[1:50]

# %%
ds
# Out:
#                                                  text  \
# 1   Log4Shell Vulnerability Poses Massive Cybersec...
# 2   yikes, what happened? catch up on #Cloud2030 d...
# 3   @Google is now adding OSS-Fuzz to the pool of ...
# 4   News Update: Conti ransomware gang exploits Lo...
# 5   Log4Shell Update: Second log4j Vulnerability P...
# 6   #cybersecurity news on the go... Brand-New Log...
# 7   When it comes to Log4Shell, some solutions req...
# 8   Log4j Vulnerability Cheatsheet\n\n🔹 How It Wor...
# 9   TWIG - A Clattering of Smart Phones - Log4Shel...
# 10  Conti ransomware gang exploits Log4Shell bug i...
# 11  Update as of Dec 17. Who has exploited #log4sh...
# 12  Log4Shell Vulnerability Poses Massive Cybersec...
# 13  @rstasiunas @thepacketrat Firstly, Log4Shell w...
# 14  @sygint @thepacketrat I use CF as a daily driv...
# 15  Protecting Against the #log4j2  (Log4Shell) Vu...
# 16  Flaws in #Lenovo laptops allow escalating to a...
# ...

# %%
ds.isnull().sum()
# Out:
# text         0
# user_name    0
# dtype: int64

# %%
tfidf = TfidfVectorizer()
train_tfidf = tfidf.fit_transform(ds.text)

# %%
ds['tfidf'] = list(train_tfidf.toarray())
# Out:
# <ipython-input-21-0c5c972ffe63>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ds['tfidf'] = list(train_tfidf.toarray())

# %%
kdtree = KDTree(train_tfidf.toarray(), leaf_size=3)

# %%
distance, idx = kdtree.query(ds['tfidf'][ds.user_name =="Brad Wood"].tolist(),k=4)
for i, value in list(enumerate(idx[0])):
    print(f"Name:{ds['user_name'][value]}")
    print(f"Distance: {distance[0][i]}")
# Out:
# Name:AJ Blackston - Financial IT Solutions Consultant
# Distance: 0.0
# Name:Brad Wood
# Distance: 1.1567301144364903
# Name:Sir Muli mit Boxhandschuh
# Distance: 1.272755228722481
# Name:Pierluigi Paganini - Security Affairs
# Distance: 1.2809345082954844
